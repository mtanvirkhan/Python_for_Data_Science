# %%
import pandas as pd
import os

# %%
# get the current working directory
print(os.getcwd())
# Out:
# c:\Users\BJIT\Anaconda Scripts\My Course\python_pandas\python inserting_column

# %%
# reading the csv file
df_exams = pd.read_csv('../StudentsPerformance.csv')
# display the dataframe content
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # insert() method

# %%
# First preparing array data of random number of 1000 records
# At first need to import numpy library
import numpy as np
new_column_data = np.random.randint(1, 100, 1000) # random number from 1 to 100 and 1000 records
new_column_data # show the data
# Out:
# array([72, 22, 51, 95, 79, 18,  4, 27, 86, 47, 35, 52, 22, 30, 87, 78, 15,
#        53, 40,  2, 32, 40, 54, 26, 67,  9, 52, 70, 69, 45, 21, 49, 25, 85,
#        99, 15, 27, 38, 98, 40, 86, 72, 82, 13, 24, 53, 94, 27, 52, 30, 83,
#        74, 88, 91, 50, 90, 88, 15, 50, 43, 27, 17,  5, 19, 97, 30, 17, 93,
#         8, 10, 78, 45, 99, 16, 72, 98, 47, 15, 72, 73, 18, 15, 19, 44, 26,
#        27, 45, 71, 58, 71, 14,  1, 52, 75, 47,  7, 84, 60, 87, 24, 13, 53,
#        98, 99, 24, 95, 24, 19, 82, 94, 68, 84, 76, 33, 51,  1, 63,  3, 34,
#        88,  4, 58, 60, 30, 96,  1, 97, 18,  8, 57, 85, 15, 26, 62, 60, 63,
#        38, 91,  4, 70, 77, 20, 50, 53, 66, 10, 48, 53,  5, 59, 19, 62, 66,
#        41, 98, 66, 27, 88, 92, 54, 76, 59, 73, 43, 72, 69, 65, 14, 59, 19,
#        21, 33,  1, 26, 50,  7, 12, 15, 25, 18, 53, 58, 90, 36, 78, 52,  7,
#        20, 86, 31, 99, 51,  6,  4, 49, 84, 43, 62, 75, 72, 39, 68, 20, 96,
# ...

# %%
# inserting column data with a name and position
df_exams.insert(2, 'insert_data', new_column_data, allow_duplicates=True)
df_exams
# Out:
#      gender race/ethnicity  insert_data parental level of education  \
# 0    female        group B           72           bachelor's degree
# 1    female        group C           22                some college
# 2    female        group B           51             master's degree
# 3      male        group A           95          associate's degree
# 4      male        group C           79                some college
# ..      ...            ...          ...                         ...
# 995  female        group E            8             master's degree
# 996    male        group C           23                 high school
# 997  female        group C           63                 high school
# 998  female        group D           18                some college
# 999  female        group D           21                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
