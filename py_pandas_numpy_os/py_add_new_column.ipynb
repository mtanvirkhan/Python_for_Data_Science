# %%
# Importing library
import pandas as pd

# %%
# Reading data from CSV file and prepare dataframe
df_exams = pd.read_csv('./StudentsPerformance.csv')
# Show dataframe data
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Add new column in a DataFrame

# %% [markdown]
# ### Adding a new column with scalar value

# %%
# Adding a column to dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ### Adding a new column with array

# %% [markdown]
# ##### The dataframe has 1000 rows, and we have to create an array of 1000 elements

# %%
# impoer numpy
import numpy as np

# %%
# creating an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the newly created array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create random integer between 1 to 100
np.random.randint(1, 100, size=1000)
# Out:
# array([15, 11, 32, 91, 27, 37, 24, 90, 82, 97, 78, 58, 21, 57, 81, 69,  8,
#        71, 22, 23, 74, 51, 50, 69, 85, 10, 50, 88,  8, 70, 34, 93, 82, 62,
#        32, 63, 68, 74, 65, 16, 18, 96,  4, 83,  8,  5, 91, 15, 17, 35, 56,
#        68, 57, 34, 29, 37, 98, 32, 13, 55, 44, 40, 99, 17, 95,  9, 52, 90,
#        49, 35, 73, 85, 81, 11, 92, 14, 52, 61, 60, 33, 66, 32, 91, 92, 84,
#        26, 95, 49, 42, 67, 80, 74, 39, 89, 42, 62, 90, 70, 11, 43,  5, 78,
#        83, 46, 28, 27, 48, 31, 12, 31, 90, 75, 73, 25, 28, 30, 71, 38, 91,
#        62, 55, 27, 89, 59, 82, 17, 17, 54, 63, 19, 12, 81, 56, 11, 86, 96,
#        45, 84,  3, 34, 78, 22, 79, 70, 62, 59, 26, 89, 56,  6, 87, 19, 55,
#        94, 45, 83,  3,  4, 17, 52, 57, 72,  7, 49, 92, 28, 79, 37, 30, 38,
#        64, 25, 10, 40, 73, 43,  3, 64, 41, 46, 90, 52, 43, 94, 52, 14, 95,
#        79, 76, 24, 37, 18, 93, 74, 39, 86, 82, 98, 81, 52, 19, 28, 92, 80,
# ...

# %%
# length of the created random number
